# %% [markdown]
# # Data Science va Sun'iy Intellekt Praktikum
#
# ## Ma'lumotlar tahlili. Pandas kutubxonasi.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/anvarnarz/praktikum_datasets/main/world_population.csv", index_col=0)

# %% [markdown]
# ### 1-VAZIFA. Yuqoridagi DF ustunlari nomini quyidagi qiymatlarga o'zgartirish va DF yuqorisidan 3 ta davlatni chiqarish
# `['davlat','zichlik_km','zichlik_mi','aholi','maydoni']`

# %%
# JAVOBNI SHUYERGA YOZING
df.columns = ['davlat','zichlik_km','zichlik_mi','aholi','maydoni']
df.head(3)
# Out:
#          davlat  zichlik_km  zichlik_mi     aholi  maydoni
# rank
# 1         Macau  21946.4667  56841.3487   658.394       30
# 2        Monaco  19755.5000  51166.7450    39.511        2
# 3     Singapore   8305.1915  21510.4461  5896.686      710

# %% [markdown]
# ## Yuqoridagi jadval dunyo davlatlarining aholi zichligi bo'yicha reytingini ko'rsatadi.
# DF indeksi sifatida davlatning zichlik reytingi olingan (aholi eng zich yashaydigan davlatlar yuqorida).
#
# **Ustunlar:**
#
# `davlat` - Davlat nomi
#
# `zichlik_km` - har 1 kv.km. ga to'g'ri keluvchi aholi soni
#
# `zichlik_mi` - har 1 kv.milyaga to'g'ri keluvchi aholi soni (milya - AQSh masofa o'lchov birligi)
#
# `aholi` - 2021-yilga ko'rsa aholi soni (ming)
#
# `maydoni` - davlat maydoni (kv.km)

# %% [markdown]
# ### 2-VAZIFA. DF oxiridan 10 ta qator chiqarish.

# %%
# JAVOBNI SHUYERGA YOZING
df.head(10)
# Out:
#             davlat  zichlik_km  zichlik_mi     aholi  maydoni
# rank
# 1            Macau  21946.4667  56841.3487   658.394       30
# 2           Monaco  19755.5000  51166.7450    39.511        2
# 3        Singapore   8305.1915  21510.4461  5896.686      710
# 4        Hong Kong   6841.3134  17719.0017  7552.810     1104
# 5        Gibraltar   5616.3333  14546.3033    33.698        6
# 6          Bahrain   2285.3542   5919.0675  1748.296      765
# 7         Maldives   1812.0567   4693.2268   543.617      300
# 8            Malta   1401.2152   3629.1473   442.784      316
# 9     Sint Maarten   1276.8235   3306.9729    43.412       34
# 10         Bermuda   1149.8148   2978.0204    62.090       54

# %% [markdown]
# ### 3-VAZIFA. DF dan 10, 20, 100, 200-indekslarda turgan davlatlarni alohida DF ko'rinishida chiqarish.

# %%
# JAVOBNI SHUYERGA YOZING
df_new = df.reindex(index=[10, 20, 100, 200])
df_new
# Out:
#            davlat  zichlik_km  zichlik_mi     aholi  maydoni
# rank
# 10        Bermuda   1149.8148   2978.0204    62.090       54
# 20          Aruba    595.5778   1542.5464   107.204      180
# 100      Slovakia    111.3592    288.4203  5460.721    49037
# 200   New Zealand     17.9713     46.5457  4860.643   270467

# %% [markdown]
# ### 4-VAZIFA. Davlatlar orasida `Uzbekistan`, `Hong-Kong`, `Antartica` borligini tekshirish

# %%
# JAVOBNI SHUYERGA YOZING
newind = pd.Index(['Uzbekistan', 'Hong-Kong', 'Antartica'])
df['davlat']
newind.isin(df['davlat'])
# Out:
# array([ True, False, False])

# %% [markdown]
# ### 5-VAZIFA.
# #### 5.1 DFning `davlat` nomli ustunini uning indeksi qilib belgilash.
# #### 5.2 `davlat` ustunini tashlab yuborish.
# #### 5.3 DFni davlat nomi bo'yicha tartiblash

# %%
#5.1
df_new = df.set_index('davlat')
df_new
# Out:
#                   zichlik_km  zichlik_mi     aholi  maydoni
# davlat
# Macau             21946.4667  56841.3487   658.394       30
# Monaco            19755.5000  51166.7450    39.511        2
# Singapore          8305.1915  21510.4461  5896.686      710
# Hong Kong          6841.3134  17719.0017  7552.810     1104
# Gibraltar          5616.3333  14546.3033    33.698        6
# ...                      ...         ...       ...      ...
# Namibia               3.1338      8.1166  2587.344   825615
# Western Sahara        2.3003      5.9577   611.875   266000
# Mongolia              2.1286      5.5129  3329.289  1564110
# Falkland Islands      0.2902      0.7517     3.533    12173
# Greenland             0.0263      0.0680    56.877  2166086
#
# [232 rows x 4 columns]

# %%
#5.2
df.drop(columns='davlat')
# Out:
#       zichlik_km  zichlik_mi     aholi  maydoni
# rank
# 1     21946.4667  56841.3487   658.394       30
# 2     19755.5000  51166.7450    39.511        2
# 3      8305.1915  21510.4461  5896.686      710
# 4      6841.3134  17719.0017  7552.810     1104
# 5      5616.3333  14546.3033    33.698        6
# ...          ...         ...       ...      ...
# 228       3.1338      8.1166  2587.344   825615
# 229       2.3003      5.9577   611.875   266000
# 230       2.1286      5.5129  3329.289  1564110
# 231       0.2902      0.7517     3.533    12173
# 232       0.0263      0.0680    56.877  2166086
#
# [232 rows x 4 columns]

# %%
df_new.aholi.loc['Malaysia']
# Out:
# np.float64(32776.194)

# %% [markdown]
# ### 6-VAZIFA. DF dan `Uzbekistan`, `Malaysia`, `South Korea`, `France` davlatlari `aholi` va `maydoni` ustunlari bilan alohida DF ko'rinishida ajratib olish.

# %%
# JAVOBNI SHUYERGA YOZING
df_new2 = df_new.loc[['Uzbekistan', 'Malaysia', 'South Korea', 'France'], ['aholi', 'maydoni']]
df_new2
# Out:
#                  aholi  maydoni
# davlat
# Uzbekistan   33935.763   447400
# Malaysia     32776.194   330803
# South Korea  51305.186   100210
# France       65426.179   551695

# %% [markdown]
# ### 7-VAZIFA. Asl DFning `aholi` ustuni qiymatlarini 1000 ga ko'paytirish.

# %%
# JAVOBNI SHUYERGA YOZING
df_new['aholi'] = df_new['aholi']*1000
df_new.sort_index().head()
# Out:
#                 zichlik_km  zichlik_mi         aholi  maydoni
# davlat
# Afghanistan        61.0757    158.1862  3.983543e+16   652230
# Albania            99.9351    258.8318  2.872933e+15    28748
# Algeria            18.7328     48.5179  4.461662e+16  2381741
# American Samoa    276.8844    717.1307  5.510000e+13      199
# Andorra           165.2885    428.0971  7.735500e+13      468

# %% [markdown]
# DF ni `aholi` ustuni bo'yicha kamayish tartibida tahlash va aholisi eng kam 10 ta davlatni chiqarish.

# %%
# JAVOBNI SHUYERGA YOZING
df_new.sort_index().sort_values(by='aholi', ascending=False).head()
# Out:
#                zichlik_km  zichlik_mi         aholi  maydoni
# davlat
# China            148.7815    385.3441  1.444216e+18  9706961
# India            423.8391   1097.7432  1.393409e+18  3287590
# United States     35.5200     91.9968  3.329151e+17  9372610
# Indonesia        145.1046    375.8210  2.763618e+17  1904569
# Pakistan         255.3542    661.3674  2.251999e+17   881912

# %% [markdown]
# ### 8-VAZIFA. DFni `maydoni` bo'yicha reytinglash (rank) va reytinglarni yangi `rank` ustuniga yozish.

# %%
# JAVOBNI SHUYERGA YOZING
df_new['rank'] = df_new['maydoni'].rank()
df_new.sort_index()
# Out:
#                    zichlik_km  zichlik_mi         aholi  maydoni   rank
# davlat
# Afghanistan           61.0757    158.1862  3.983543e+16   652230  192.0
# Albania               99.9351    258.8318  2.872933e+15    28748   89.0
# Algeria               18.7328     48.5179  4.461662e+16  2381741  223.0
# American Samoa       276.8844    717.1307  5.510000e+13      199   20.0
# Andorra              165.2885    428.0971  7.735500e+13      468   38.0
# ...                       ...         ...           ...      ...    ...
# Wallis and Futuna     78.1268    202.3483  1.109400e+13      142   15.0
# Western Sahara         2.3003      5.9577  6.118750e+14   266000  155.0
# Yemen                 57.7509    149.5749  3.049064e+16   527968  183.0
# Zambia                25.1400     65.1125  1.892065e+16   752612  194.0
# Zimbabwe              38.6229    100.0333  1.509217e+16   390757  172.0
#
# [232 rows x 5 columns]

# %% [markdown]
# #### `Uzbekistan`, `United Kingdom`, `Indonesia` davlatlari alohida df ko'rinishida chiqarish

# %%
# JAVOBNI SHUYERGA YOZING
df_new3 = df_new.loc[['Uzbekistan', 'United Kingdom', 'Indonesia']]
df_new3
# Out:
#                 zichlik_km  zichlik_mi         aholi  maydoni   rank
# davlat
# Uzbekistan         75.8511    196.4542  3.393576e+16   447400  176.0
# United Kingdom    280.8033    727.2805  6.820712e+16   242900  153.0
# Indonesia         145.1046    375.8210  2.763618e+17  1904569  218.0

# %% [markdown]
# ### 9-VAZIFA. DFni `davlat` nomi bo'yicha tartiblash

# %%
# JAVOBNI SHUYERGA YOZING
df_new.sort_values(by = 'davlat').head()
# Out:
#                 zichlik_km  zichlik_mi         aholi  maydoni   rank
# davlat
# Afghanistan        61.0757    158.1862  3.983543e+16   652230  192.0
# Albania            99.9351    258.8318  2.872933e+15    28748   89.0
# Algeria            18.7328     48.5179  4.461662e+16  2381741  223.0
# American Samoa    276.8844    717.1307  5.510000e+13      199   20.0
# Andorra           165.2885    428.0971  7.735500e+13      468   38.0

# %% [markdown]
# #### DFdan 10,50,100,200-o'rinda turgan davlatlarni alohida DF ko'rinishida chiqarish

# %%
# JAVOBNI SHUYERGA YOZING
df_new.iloc[[10, 50, 100, 200]]
# Out:
#                      zichlik_km  zichlik_mi         aholi  maydoni   rank
# davlat
# Bangladesh            1126.9465   2918.7915  1.663035e+17   147570  139.0
# Trinidad and Tobago    273.5624    708.5266  1.403375e+15     5130   61.0
# Benin                  110.5560    286.3401  1.245104e+16   112622  131.0
# Paraguay                17.7495     45.9712  7.219638e+15   406752  173.0

# %% [markdown]
# ### 10-VAZIFA. Quyidagi davlatlarning `aholi` sonini oddiy son ko'rinishida chiqarish:
# - `Malaysia`
# - `Nigeria`
# - `Nepal`
# - `Italy`

# %%
# JAVOBNI SHUYERGA YOZING
df_new.loc['Uzbekistan']['aholi']/1000_000_000
# Out:
# np.float64(33935763.0)

# %%
df_new.loc['Malaysia']['aholi']/1000_000_000
# Out:
# np.float64(32776194.000000004)

# %%
df_new.loc['Nigeria']['aholi']/1000_000_000
# Out:
# np.float64(211400708.0)

# %%
df_new.loc['Italy']['aholi']/1000_000_000
# Out:
# np.float64(60367477.0)
